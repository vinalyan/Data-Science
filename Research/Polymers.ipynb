# %%
import pandas as pd

# %%
df = pd.read_excel("D:/Usuarios/rhaps/OneDrive/Research/polimeros/Excel con 86 referencias.xlsx")

df.head()
# Out:
#                                           Referencia  \
# 0  (Abdulkhani, Hosseinzadeh, Ashori, Dadashi, & ...
# 1  (Abdulkhani, Hosseinzadeh, Ashori, Dadashi, & ...
# 2  (Abdulkhani, Hosseinzadeh, Ashori, Dadashi, & ...
# 3  (Abdulkhani, Hosseinzadeh, Ashori, Dadashi, & ...
# 4  Bio-nanocomposite films reinforced with cellul...
#
#                                           Unnamed: 1 Componente 1  \
# 0  (Abdulkhani, Hosseinzadeh, Ashori, Dadashi, & ...          PLA
# 1                                                NaN          PLA
# 2                                                NaN          PLA
# 3                                                NaN          PLA
# 4  Bio-nanocomposite films reinforced with cellul...          CMC
#
#   Componente 2 Relleno  Porcentaje del relleno  Módulo tensil (GPa)  \
# 0          NaN     NaN                     0.0                1.170
# 1          NaN     CNF                     1.0                1.130
# 2          NaN     CNF                     3.0                1.200
# 3          NaN     CNF                     5.0                2.120
# 4          NaN     NaN                     0.0                1.066
#
#    Resistencial tensil (MPa)  Elasticidad (%)  Resistencia * Elasticidad  \
# 0                      15.20            40.30                   612.5600
# 1                      16.70            64.80                  1082.1600
# 2                      33.10           188.90                  6252.5900
# 3                      30.50            14.60                   445.3000
# 4                      76.23            22.99                  1752.5277
#
#    Permeabilidad sin multiplicar  Permeabilidad del vapor de agua (g/m*h*Pa)  \
# 0                            NaN                                6.732000e-08
# 1                            NaN                                7.236000e-08
# 2                            NaN                                7.560000e-08
# 3                            NaN                                9.288000e-08
# 4                            NaN                                1.360000e-07
#
#    T a 90% de peso restante (°C)  T a 60% de peso restante (°C)  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#    T a 30% de peso restante (°C) Tg (°C) Tm (°C)
# 0                            NaN    57.5   156.3
# 1                            NaN    58.3   150.6
# 2                            NaN    58.5   154.2
# 3                            NaN    58.9   154.1
# 4                            NaN     NaN     NaN

# %%
df.dtypes
# Out:
# Referencia                                     object
# Unnamed: 1                                     object
# Componente 1                                   object
# Componente 2                                   object
# Relleno                                        object
# Porcentaje del relleno                        float64
# Módulo tensil (GPa)                           float64
# Resistencial tensil (MPa)                     float64
# Elasticidad (%)                               float64
# Resistencia * Elasticidad                     float64
# Permeabilidad sin multiplicar                 float64
# Permeabilidad del vapor de agua (g/m*h*Pa)    float64
# T a 90% de peso restante (°C)                 float64
# T a 60% de peso restante (°C)                 float64
# T a 30% de peso restante (°C)                 float64
# Tg (°C)                                        object
# Tm (°C)                                        object
# dtype: object

# %%
df.describe(include='all').transpose()
# Out:
#                                            count unique  \
# Referencia                                   549     86
# Unnamed: 1                                    86     86
# Componente 1                                 549     32
# Componente 2                                 260     33
# Relleno                                      321     35
# Porcentaje del relleno                       246    NaN
# Módulo tensil (GPa)                          293    NaN
# Resistencial tensil (MPa)                    537    NaN
# Elasticidad (%)                              460    NaN
# Resistencia * Elasticidad                    460    NaN
# Permeabilidad sin multiplicar                247    NaN
# Permeabilidad del vapor de agua (g/m*h*Pa)   289    NaN
# T a 90% de peso restante (°C)                 87    NaN
# T a 60% de peso restante (°C)                 87    NaN
# T a 30% de peso restante (°C)                 87    NaN
# Tg (°C)                                       98     88
# Tm (°C)                                      112     97
#
#                                                                                           top  \
# Referencia                                  Chitosan/clay nanocomposite films as supports ...
# Unnamed: 1                                  Producing novel edible films from semi refined...
# Componente 1                                                                               CH
# Componente 2                                                                         Glicerol
# Relleno                                                                                   CNC
# Porcentaje del relleno                                                                    NaN
# Módulo tensil (GPa)                                                                       NaN
# Resistencial tensil (MPa)                                                                 NaN
# Elasticidad (%)                                                                           NaN
# Resistencia * Elasticidad                                                                 NaN
# Permeabilidad sin multiplicar                                                             NaN
# Permeabilidad del vapor de agua (g/m*h*Pa)                                                NaN
# T a 90% de peso restante (°C)                                                             NaN
# T a 60% de peso restante (°C)                                                             NaN
# T a 30% de peso restante (°C)                                                             NaN
# Tg (°C)                                                                                  62.5
# Tm (°C)                                                                                   152
#
#                                            freq         mean          std  \
# Referencia                                   16          NaN          NaN
# Unnamed: 1                                    1          NaN          NaN
# Componente 1                                162          NaN          NaN
# Componente 2                                 64          NaN          NaN
# Relleno                                     114          NaN          NaN
# Porcentaje del relleno                      NaN      5.01911      11.9393
# Módulo tensil (GPa)                         NaN      2.50083      6.78352
# Resistencial tensil (MPa)                   NaN      37.8108      49.6665
# Elasticidad (%)                             NaN      40.3081      59.8858
# Resistencia * Elasticidad                   NaN      1143.54      1892.16
# Permeabilidad sin multiplicar               NaN      141.079      978.909
# Permeabilidad del vapor de agua (g/m*h*Pa)  NaN  4.89912e-06  3.30584e-05
# T a 90% de peso restante (°C)               NaN      211.571      89.3684
# T a 60% de peso restante (°C)               NaN      302.621      42.8063
# T a 30% de peso restante (°C)               NaN      411.816      106.359
# Tg (°C)                                       6          NaN          NaN
# Tm (°C)                                       6          NaN          NaN
#
#                                                  min         25%          50%  \
# Referencia                                       NaN         NaN          NaN
# Unnamed: 1                                       NaN         NaN          NaN
# Componente 1                                     NaN         NaN          NaN
# Componente 2                                     NaN         NaN          NaN
# Relleno                                          NaN         NaN          NaN
# Porcentaje del relleno                             0           0            1
# Módulo tensil (GPa)                         0.003527       0.267         0.92
# Resistencial tensil (MPa)                      0.025        12.3         27.1
# Elasticidad (%)                                 1.46         7.5       21.185
# Resistencia * Elasticidad                      13.02     160.743      483.656
# Permeabilidad sin multiplicar                1.7e-14    7.15e-11     2.93e-10
# Permeabilidad del vapor de agua (g/m*h*Pa)  6.12e-11  1.6812e-07  5.18135e-07
# T a 90% de peso restante (°C)                   66.1         139          208
# T a 60% de peso restante (°C)                    197       271.5          302
# T a 30% de peso restante (°C)                    269       342.5          366
# Tg (°C)                                          NaN         NaN          NaN
# Tm (°C)                                          NaN         NaN          NaN
#
#                                                    75%         max
# Referencia                                         NaN         NaN
# Unnamed: 1                                         NaN         NaN
# Componente 1                                       NaN         NaN
# Componente 2                                       NaN         NaN
# Relleno                                            NaN         NaN
# Porcentaje del relleno                               5         100
# Módulo tensil (GPa)                              1.917          60
# Resistencial tensil (MPa)                           47         656
# Elasticidad (%)                                   44.8       491.7
# Resistencia * Elasticidad                      1426.11     14882.4
# Permeabilidad sin multiplicar                9.435e-05       13600
# Permeabilidad del vapor de agua (g/m*h*Pa)  1.2816e-06  0.00035856
# T a 90% de peso restante (°C)                      290         353
# T a 60% de peso restante (°C)                      342         380
# T a 30% de peso restante (°C)                      474         650
# Tg (°C)                                            NaN         NaN
# Tm (°C)                                            NaN         NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 549 entries, 0 to 548
# Data columns (total 17 columns):
# Referencia                                    549 non-null object
# Unnamed: 1                                    86 non-null object
# Componente 1                                  549 non-null object
# Componente 2                                  260 non-null object
# Relleno                                       321 non-null object
# Porcentaje del relleno                        246 non-null float64
# Módulo tensil (GPa)                           293 non-null float64
# Resistencial tensil (MPa)                     537 non-null float64
# Elasticidad (%)                               460 non-null float64
# Resistencia * Elasticidad                     460 non-null float64
# Permeabilidad sin multiplicar                 247 non-null float64
# Permeabilidad del vapor de agua (g/m*h*Pa)    289 non-null float64
# T a 90% de peso restante (°C)                 87 non-null float64
# T a 60% de peso restante (°C)                 87 non-null float64
# T a 30% de peso restante (°C)                 87 non-null float64
# Tg (°C)                                       98 non-null object
# Tm (°C)                                       112 non-null object
# dtypes: float64(10), object(7)
# memory usage: 73.0+ KB

# %% [markdown]
# As we can see the next features have the most number of NaNs:
#
# + unamed (89%)
# + Componente 2 (52%)
# + Porcentaje del relleno (55%)
# + Modulo tensil (46%)
# + Permeabilidad sin multiplicar (55%)
# + permeabilidad del vapor de agua (47%)
# + T a 90% ...
# + T a 60% ...
# + T a 30% ...
# + tg ...
# + tm ...
#
# is it neccesary to have the feature "Resistencia * Elasticidad" that is a math result from other two columns? for this first experiment we aren't going to use it

# %%
df2 = df[['Componente 1', 'Relleno', 'Resistencial tensil (MPa)', 'Elasticidad (%)']].copy()


df2.describe(include='all')
# Out:
#        Componente 1 Relleno  Resistencial tensil (MPa)  Elasticidad (%)
# count           549     321                 537.000000       460.000000
# unique           32      35                        NaN              NaN
# top              CH     CNC                        NaN              NaN
# freq            162     114                        NaN              NaN
# mean            NaN     NaN                  37.810831        40.308072
# std             NaN     NaN                  49.666473        59.885807
# min             NaN     NaN                   0.025000         1.460000
# 25%             NaN     NaN                  12.300000         7.500000
# 50%             NaN     NaN                  27.100000        21.185000
# 75%             NaN     NaN                  47.000000        44.800000
# max             NaN     NaN                 656.000000       491.700000

# %% [markdown]
# Relleno has 228 NaNs, I'm going to make a sub dataset in order to erase all the NaNs in "Relleno", so I'm going to replace them with another category "Nada".

# %%
df2[df2.Relleno.isna()]= "NADA"

# %% [markdown]
# In the same way, "Resistencial tensil (MPa)" and "Elasticidad (%)" have some NaNs, but they are quantitative features. We might use a fill statistical technique in the NaN values.

# %%
df2[df2.Re]
